# %% [markdown]
# ## Rega
#
# ### Solos
#
# Descrição Literária (Embrapa) | Categoria Hídrica | Frequência (Dias) | Justificativa Agronômica
# "Brejos", "Várzeas alagadas", "Solos paludosos" | Muito Alta | 3 | Plantas adaptadas a ambientes ripários severos. No canteiro, a terra não pode secar na superfície.
# "Solos úmidos"/"Matas de galeria"/"Matas ciliares" | Alta | 5 | Exigem umidade constante, mas sem encharcamento diário. Ideal para espécies de capoeirões úmidos.
# "Solos bem drenados"/"Solos profundos e férteis" | Moderada | 7 a 10 | O padrão para a maioria das árvores de matas semidecíduas. Permite que o solo respire e seque levemente.
# "Solos secos"/"Tolerante à seca"/"Terrenos pedregosos" | Rústica/Baixa | 15 | Plantas de Cerrado, Caatinga ou transições secas. Muita água apodrece o sistema radicular.

# %%
| Speed | Direction | Location |
|---|---|---|
| 60 mph | North | New York |
# Out:
# Running cells with '.venv (Python -1.-1.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Projetos/SaberDoChao/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ## Quantidade de Sol
#
# Características Silviculturais
